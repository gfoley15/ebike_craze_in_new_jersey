# %%
import pandas as pd
import glob
from datetime import datetime

# %%
files = glob.glob('../sourcedata/*.csv')

# %%
dfs = []

# %%
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
combined_df = pd.concat(dfs, ignore_index=True)

# %%
len(combined_df)
# Out:
# 1239822

# %%
combined_df.dropna()
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1        B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2        5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3        E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4        323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                   ...            ...                  ...
# 1239817  CE90C772574D5E70  electric_bike  2024-04-21 15:56:52
# 1239818  70D59D4F56BAA44C  electric_bike  2024-04-21 16:11:20
# 1239819  919C8DE40AC18B29  electric_bike  2024-04-26 17:48:39
# 1239820  46D5752D4AFF2E1B   classic_bike  2024-04-16 13:20:32
# 1239821  F79D0248A8361A64  electric_bike  2024-04-07 14:11:42
#
#                     ended_at                        start_station_name  \
# 0        2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1        2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# 2        2023-01-29 15:32:38  Hoboken Terminal - Hudson St & Hudson Pl
# 3        2023-01-24 18:42:13  Hoboken Terminal - Hudson St & Hudson Pl
# 4        2023-01-21 20:48:08                             Hamilton Park
# ...                      ...                                       ...
# 1239817  2024-04-21 16:07:13                            Columbus Drive
# 1239818  2024-04-21 16:19:33                            Columbus Drive
# 1239819  2024-04-26 17:55:20                            Columbus Drive
# 1239820  2024-04-16 13:35:39                            Columbus Drive
# 1239821  2024-04-07 14:22:13                            Columbus Drive
#
#         start_station_id                            end_station_name  \
# 0                  HB101                               Hamilton Park
# 1                  HB101  Southwest Park - Jackson St & Observer Hwy
# 2                  HB101                          Marshall St & 2 St
# 3                  HB101                               Hamilton Park
# 4                  JC009                                Manila & 1st
# ...                  ...                                         ...
# 1239817            JC014                       Baldwin at Montgomery
# 1239818            JC014                       Baldwin at Montgomery
# 1239819            JC014                       Baldwin at Montgomery
# 1239820            JC014                       Baldwin at Montgomery
# 1239821            JC014                       Baldwin at Montgomery
#
#         end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 0                JC009  40.735938 -74.030305  40.727596 -74.044247
# 1                HB401  40.735938 -74.030305  40.737551 -74.041664
# 2                HB408  40.735944 -74.030383  40.740802 -74.042521
# 3                JC009  40.735986 -74.030364  40.727596 -74.044247
# 4                JC082  40.727596 -74.044247  40.721651 -74.042884
# ...                ...        ...        ...        ...        ...
# 1239817          JC020  40.718618 -74.038553  40.723659 -74.064194
# 1239818          JC020  40.718847 -74.038642  40.723659 -74.064194
# 1239819          JC020  40.719039 -74.038610  40.723659 -74.064194
# 1239820          JC020  40.718355 -74.038914  40.723659 -74.064194
# 1239821          JC020  40.718823 -74.038696  40.723659 -74.064194
#
#         member_casual
# 0              member
# 1              member
# 2              member
# 3              member
# 4              member
# ...               ...
# 1239817        casual
# 1239818        casual
# 1239819        member
# 1239820        member
# 1239821        casual
#
# [1235686 rows x 13 columns]

# %%
len(combined_df)
# Out:
# 1239822

# %%
combined_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])

# %%
combined_df.to_csv('../combineddata/combined_citi_bike.csv')
